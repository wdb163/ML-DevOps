# %%
import seaborn # Seaborn is a Python data visualization library based on matplotlib.
import pandas as pd # Python Data Analysis Library
import wandb # Weights and Biases
import ydata_profiling # A highly popular Python library that automates the Exploratory Data Analysis (EDA) process

# %%
run = wandb.init(
    project="exercise_4",
    job_type="eda",
    save_code=True
)
# Out:
# Finishing previous runs because reinit is set to 'default'.
# uploading artifact source-exercise_4-_workspace_nd0821-c2-build-model-workflow-exe..loration-and-preparation_exercises_exercise_4_starter_EDA.ipynb (2.0s)
#  View run <strong style="color:#cdcd00">grateful-paper-6</strong> at: <a href='https://wandb.ai/benjamin-m-cohen00-caci-international/exercise_4/runs/iat92a5z' target="_blank">https://wandb.ai/benjamin-m-cohen00-caci-international/exercise_4/runs/iat92a5z</a><br> View project at: <a href='https://wandb.ai/benjamin-m-cohen00-caci-international/exercise_4' target="_blank">https://wandb.ai/benjamin-m-cohen00-caci-international/exercise_4</a><br>Synced 5 W&B file(s), 0 media file(s), 9 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260617_200942-iat92a5z/logs</code>
# Waiting for wandb.init()...
# Tracking run with wandb version 0.24.0
# ...

# %%
artifact = run.use_artifact("exercise_4/genres_mod.parquet:latest")
df = pd.read_parquet(artifact.file())
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5       NaN     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo            type  duration_ms  \
# 0          0.013400    0.0556   0.3890  156.985  audio_features       124539
# 1          0.000000    0.1180   0.1240  115.080  audio_features       224427
# 2          0.000004    0.3720   0.0391  218.050  audio_features        98821
# 3          0.000000    0.1140   0.1750  186.948  audio_features       123661
# 4          0.000000    0.1660   0.5910  147.988  audio_features       123298
#
# ...

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
profile
print(df.duplicated().sum())
df = df.drop_duplicates().reset_index(drop=True)
# Out:
# 921

# %%
run.finish()
# Out:
# uploading summary (0.2s)
#  View run <strong style="color:#cdcd00">confused-shadow-7</strong> at: <a href='https://wandb.ai/benjamin-m-cohen00-caci-international/exercise_4/runs/0sq8qjz5' target="_blank">https://wandb.ai/benjamin-m-cohen00-caci-international/exercise_4/runs/0sq8qjz5</a><br> View project at: <a href='https://wandb.ai/benjamin-m-cohen00-caci-international/exercise_4' target="_blank">https://wandb.ai/benjamin-m-cohen00-caci-international/exercise_4</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260617_201009-0sq8qjz5/logs</code>
